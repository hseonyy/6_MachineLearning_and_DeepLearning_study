# %% [markdown]
# # **1. 뉴런(neuron)**

# %% [markdown]
# ### 1-1. 생물학적 뉴런
# * 인간의 뇌는 수십억 개의 뉴런을 가지고 있음
# * 뉴런은 화학적, 전기적 신호를 처리하고 전달하는 연결된 뇌신경 세포
#
# ![](https://i.imgur.com/j3yx4zF.jpg)

# %% [markdown]
# ### 1-2. 인공 뉴런
# * 1943년에 워렌 맥컬록, 월터 피츠가 단순화된 뇌세포 개념을 발표
# * 신경 세포를 이진 출력을 가진 단순한 논리 게이트라고 설명
# * 생물학적 뉴런의 모델에 기초한 수학적 기능으로 각 뉴런이 입력을 받아 개별적으로 가중치를 곱하여 나온 합계를 비선형 함수를 전달하여 출력을 생성

# %% [markdown]
# # **2. 퍼셉트론(Perceptron)**
# * 인공 신경망의 가장 기본적인 형태로 1957년에 처음 소개됨
# * 입력과 출력을 가진 단일 뉴런 모델을 기반
# * 초기에 기계 학습 알고리즘 중 하나로 이진 분류 문제를 해결하기 위해 설계

# %% [markdown]
# ### 2-1. 논리 회귀(단층 퍼셉트론)로 AND 문제 풀기
#
# ![](https://i.imgur.com/yt7O7TV.jpg)

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
X = torch.FloatTensor([[0, 0], [0, 1], [1, 0], [1, 1]])
y = torch.FloatTensor([[0], [0], [0], [1]])

model = nn.Sequential(
    nn.Linear(2, 1),
    nn.Sigmoid()
)

optimizer = optim.SGD(model.parameters(), lr=1)

epochs = 1000

for epoch in range(epochs + 1):
    y_pred = model(X)
    loss = nn.BCELoss()(y_pred, y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if epoch % 100 == 0:
        y_bool = (y_pred >= 0.5).float()
        accuracy = (y == y_bool).float().sum() / len(y) * 100
        print(f'Epoch {epoch:4d}/{epochs} Loss: {loss:.6f} Accuracy: {accuracy:.2f}%')
# Out:
# Epoch    0/1000 Loss: 0.797080 Accuracy: 25.00%
# Epoch  100/1000 Loss: 0.143892 Accuracy: 100.00%
# Epoch  200/1000 Loss: 0.081692 Accuracy: 100.00%
# Epoch  300/1000 Loss: 0.056543 Accuracy: 100.00%
# Epoch  400/1000 Loss: 0.043049 Accuracy: 100.00%
# Epoch  500/1000 Loss: 0.034677 Accuracy: 100.00%
# Epoch  600/1000 Loss: 0.028994 Accuracy: 100.00%
# Epoch  700/1000 Loss: 0.024891 Accuracy: 100.00%
# Epoch  800/1000 Loss: 0.021794 Accuracy: 100.00%
# Epoch  900/1000 Loss: 0.019375 Accuracy: 100.00%
# Epoch 1000/1000 Loss: 0.017435 Accuracy: 100.00%

# %% [markdown]
# ### 2-2. 논리 회귀(단층 퍼셉트론)로 OR 문제 풀기

# %%
X = torch.FloatTensor([[0, 0], [0, 1], [1, 0], [1, 1]])
y = torch.FloatTensor([[0], [1], [1], [1]])

model = nn.Sequential(
    nn.Linear(2, 1),
    nn.Sigmoid()
)

optimizer = optim.SGD(model.parameters(), lr=1)

epochs = 1000

for epoch in range(epochs + 1):
    y_pred = model(X)
    loss = nn.BCELoss()(y_pred, y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if epoch % 100 == 0:
        y_bool = (y_pred >= 0.5).float()
        accuracy = (y == y_bool).float().sum() / len(y) * 100
        print(f'Epoch {epoch:4d}/{epochs} Loss: {loss:.6f} Accuracy: {accuracy:.2f}%')
# Out:
# Epoch    0/1000 Loss: 0.856441 Accuracy: 25.00%
# Epoch  100/1000 Loss: 0.089805 Accuracy: 100.00%
# Epoch  200/1000 Loss: 0.047035 Accuracy: 100.00%
# Epoch  300/1000 Loss: 0.031497 Accuracy: 100.00%
# Epoch  400/1000 Loss: 0.023581 Accuracy: 100.00%
# Epoch  500/1000 Loss: 0.018809 Accuracy: 100.00%
# Epoch  600/1000 Loss: 0.015628 Accuracy: 100.00%
# Epoch  700/1000 Loss: 0.013360 Accuracy: 100.00%
# Epoch  800/1000 Loss: 0.011662 Accuracy: 100.00%
# Epoch  900/1000 Loss: 0.010344 Accuracy: 100.00%
# Epoch 1000/1000 Loss: 0.009292 Accuracy: 100.00%

# %% [markdown]
# ### 2-3. 논리 회귀(단층 퍼셉트론)로 XOR 문제 풀기
#
# ![](https://i.imgur.com/55pt51n.png)

# %%
X = torch.FloatTensor([[0, 0], [0, 1], [1, 0], [1, 1]])
y = torch.FloatTensor([[0], [1], [1], [0]])

model = nn.Sequential(
    nn.Linear(2, 1),
    nn.Sigmoid()
)

optimizer = optim.SGD(model.parameters(), lr=1)

epochs = 1000

for epoch in range(epochs + 1):
    y_pred = model(X)
    loss = nn.BCELoss()(y_pred, y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if epoch % 100 == 0:
        y_bool = (y_pred >= 0.5).float()
        accuracy = (y == y_bool).float().sum() / len(y) * 100
        print(f'Epoch {epoch:4d}/{epochs} Loss: {loss:.6f} Accuracy: {accuracy:.2f}%')
# Out:
# Epoch    0/1000 Loss: 0.720350 Accuracy: 25.00%
# Epoch  100/1000 Loss: 0.693148 Accuracy: 75.00%
# Epoch  200/1000 Loss: 0.693147 Accuracy: 75.00%
# Epoch  300/1000 Loss: 0.693147 Accuracy: 75.00%
# Epoch  400/1000 Loss: 0.693147 Accuracy: 50.00%
# Epoch  500/1000 Loss: 0.693147 Accuracy: 50.00%
# Epoch  600/1000 Loss: 0.693147 Accuracy: 50.00%
# Epoch  700/1000 Loss: 0.693147 Accuracy: 50.00%
# Epoch  800/1000 Loss: 0.693147 Accuracy: 50.00%
# Epoch  900/1000 Loss: 0.693147 Accuracy: 50.00%
# Epoch 1000/1000 Loss: 0.693147 Accuracy: 50.00%

# %% [markdown]
# ### 2-4. 다층 퍼셉트론으로 XOR 문제 풀기
# * 여러개의 은닉층을 만들어 해결
# * https://colah.github.io/posts/2015-09-NN-Types-FP/

# %%
model = nn.Sequential(
    nn.Linear(2, 64),
    nn.Sigmoid(),
    nn.Linear(64, 32),
    nn.Sigmoid(),
    nn.Linear(32, 16),
    nn.Sigmoid(),
    nn.Linear(16, 1),
    nn.Sigmoid()
)

print(model)
# Out:
# Sequential(
#   (0): Linear(in_features=2, out_features=64, bias=True)
#   (1): Sigmoid()
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): Sigmoid()
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): Sigmoid()
#   (6): Linear(in_features=16, out_features=1, bias=True)
#   (7): Sigmoid()
# )

# %%
X = torch.FloatTensor([[0, 0], [0, 1], [1, 0], [1, 1]])
y = torch.FloatTensor([[0], [1], [1], [0]])

optimizer = optim.SGD(model.parameters(), lr=1)

epochs = 5000

for epoch in range(epochs + 1):
    y_pred = model(X)
    loss = nn.BCELoss()(y_pred, y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if epoch % 100 == 0:
        y_bool = (y_pred >= 0.5).float()
        accuracy = (y == y_bool).float().sum() / len(y) * 100
        print(f'Epoch {epoch:4d}/{epochs} Loss: {loss:.6f} Accuracy: {accuracy:.2f}%')
# Out:
# Epoch    0/5000 Loss: 0.722838 Accuracy: 50.00%
# Epoch  100/5000 Loss: 0.693142 Accuracy: 50.00%
# Epoch  200/5000 Loss: 0.693131 Accuracy: 50.00%
# Epoch  300/5000 Loss: 0.693120 Accuracy: 50.00%
# Epoch  400/5000 Loss: 0.693108 Accuracy: 50.00%
# Epoch  500/5000 Loss: 0.693096 Accuracy: 50.00%
# Epoch  600/5000 Loss: 0.693081 Accuracy: 50.00%
# Epoch  700/5000 Loss: 0.693065 Accuracy: 75.00%
# Epoch  800/5000 Loss: 0.693046 Accuracy: 75.00%
# Epoch  900/5000 Loss: 0.693024 Accuracy: 75.00%
# Epoch 1000/5000 Loss: 0.692997 Accuracy: 75.00%
# Epoch 1100/5000 Loss: 0.692964 Accuracy: 75.00%
# Epoch 1200/5000 Loss: 0.692923 Accuracy: 75.00%
# Epoch 1300/5000 Loss: 0.692870 Accuracy: 75.00%
# Epoch 1400/5000 Loss: 0.692801 Accuracy: 75.00%
# Epoch 1500/5000 Loss: 0.692708 Accuracy: 75.00%
# Epoch 1600/5000 Loss: 0.692578 Accuracy: 75.00%
# Epoch 1700/5000 Loss: 0.692389 Accuracy: 75.00%
# Epoch 1800/5000 Loss: 0.692098 Accuracy: 75.00%
# Epoch 1900/5000 Loss: 0.691617 Accuracy: 75.00%
# Epoch 2000/5000 Loss: 0.690732 Accuracy: 75.00%
# Epoch 2100/5000 Loss: 0.688826 Accuracy: 75.00%
# Epoch 2200/5000 Loss: 0.683495 Accuracy: 75.00%
# Epoch 2300/5000 Loss: 0.659698 Accuracy: 75.00%
# Epoch 2400/5000 Loss: 0.589921 Accuracy: 25.00%
# Epoch 2500/5000 Loss: 0.426432 Accuracy: 50.00%
# Epoch 2600/5000 Loss: 0.021975 Accuracy: 100.00%
# Epoch 2700/5000 Loss: 0.007968 Accuracy: 100.00%
# Epoch 2800/5000 Loss: 0.004570 Accuracy: 100.00%
# Epoch 2900/5000 Loss: 0.003124 Accuracy: 100.00%
# Epoch 3000/5000 Loss: 0.002342 Accuracy: 100.00%
# Epoch 3100/5000 Loss: 0.001858 Accuracy: 100.00%
# Epoch 3200/5000 Loss: 0.001531 Accuracy: 100.00%
# Epoch 3300/5000 Loss: 0.001297 Accuracy: 100.00%
# Epoch 3400/5000 Loss: 0.001122 Accuracy: 100.00%
# Epoch 3500/5000 Loss: 0.000987 Accuracy: 100.00%
# Epoch 3600/5000 Loss: 0.000879 Accuracy: 100.00%
# Epoch 3700/5000 Loss: 0.000791 Accuracy: 100.00%
# Epoch 3800/5000 Loss: 0.000719 Accuracy: 100.00%
# Epoch 3900/5000 Loss: 0.000658 Accuracy: 100.00%
# Epoch 4000/5000 Loss: 0.000606 Accuracy: 100.00%
# Epoch 4100/5000 Loss: 0.000561 Accuracy: 100.00%
# Epoch 4200/5000 Loss: 0.000522 Accuracy: 100.00%
# Epoch 4300/5000 Loss: 0.000488 Accuracy: 100.00%
# Epoch 4400/5000 Loss: 0.000458 Accuracy: 100.00%
# Epoch 4500/5000 Loss: 0.000431 Accuracy: 100.00%
# Epoch 4600/5000 Loss: 0.000407 Accuracy: 100.00%
# Epoch 4700/5000 Loss: 0.000386 Accuracy: 100.00%
# Epoch 4800/5000 Loss: 0.000366 Accuracy: 100.00%
# Epoch 4900/5000 Loss: 0.000348 Accuracy: 100.00%
# Epoch 5000/5000 Loss: 0.000332 Accuracy: 100.00%
